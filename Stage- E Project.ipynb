# %%
#Importing the libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime

# %%
import parser
Household_data = pd.read_csv(r'C:\Users\user\path\household_power_consumption.txt', sep=";", header = None, engine='python',parse_dates=[0])
Household_data.head()
# Out:
#             0         1                    2                      3        4  \
# 0        Date      Time  Global_active_power  Global_reactive_power  Voltage
# 1  16/12/2006  17:24:00                4.216                  0.418  234.840
# 2  16/12/2006  17:25:00                5.360                  0.436  233.630
# 3  16/12/2006  17:26:00                5.374                  0.498  233.290
# 4  16/12/2006  17:27:00                5.388                  0.502  233.740
#
#                   5               6               7               8
# 0  Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 1            18.400           0.000           1.000          17.000
# 2            23.000           0.000           1.000          16.000
# 3            23.000           0.000           2.000          17.000
# 4            23.000           0.000           1.000          17.000

# %%
column= {0: 'Date', 1: 'Time', 2: 'Global_active_power', 3: 'Global_reactive_power', 4: 'Voltage', 5: 'Global_intensity', 6: 'Sub_metering_1', 7: 'Sub_metering_2',8: 'Sub_metering_3'}
Household_data =Household_data.rename(columns=column)
Household_data= Household_data.iloc[1:]
#Household_data["Date"] = pd.to_datetime(Household_data["Date"])
Date= Household_data.Date
Time= Household_data.Time
Household_data
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 1        16/12/2006  17:24:00               4.216                 0.418
# 2        16/12/2006  17:25:00               5.360                 0.436
# 3        16/12/2006  17:26:00               5.374                 0.498
# 4        16/12/2006  17:27:00               5.388                 0.502
# 5        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075255  26/11/2010  20:58:00               0.946                 0.000
# 2075256  26/11/2010  20:59:00               0.944                 0.000
# 2075257  26/11/2010  21:00:00               0.938                 0.000
# 2075258  26/11/2010  21:01:00               0.934                 0.000
# 2075259  26/11/2010  21:02:00               0.932                 0.000
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2 Sub_metering_3
# ...

# %%
Household_data=Household_data[['Global_active_power', 'Global_reactive_power', 'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3']]
Household_data
# Out:
#         Global_active_power Global_reactive_power  Voltage Global_intensity  \
# 1                     4.216                 0.418  234.840           18.400
# 2                     5.360                 0.436  233.630           23.000
# 3                     5.374                 0.498  233.290           23.000
# 4                     5.388                 0.502  233.740           23.000
# 5                     3.666                 0.528  235.680           15.800
# ...                     ...                   ...      ...              ...
# 2075255               0.946                 0.000  240.430            4.000
# 2075256               0.944                 0.000  240.000            4.000
# 2075257               0.938                 0.000  239.820            3.800
# 2075258               0.934                 0.000  239.700            3.800
# 2075259               0.932                 0.000  239.550            3.800
#
#         Sub_metering_1 Sub_metering_2 Sub_metering_3
# ...

# %%
A= Household_data[['Global_reactive_power','Global_active_power']]
A.corr().head(4)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
Household_data['DateTime']= pd.to_datetime(Date.apply(str)+' '+Time)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Household_data
# Out:
#         Global_active_power Global_reactive_power  Voltage Global_intensity  \
# 1                     4.216                 0.418  234.840           18.400
# 2                     5.360                 0.436  233.630           23.000
# 3                     5.374                 0.498  233.290           23.000
# 4                     5.388                 0.502  233.740           23.000
# 5                     3.666                 0.528  235.680           15.800
# ...                     ...                   ...      ...              ...
# 2075255               0.946                 0.000  240.430            4.000
# 2075256               0.944                 0.000  240.000            4.000
# 2075257               0.938                 0.000  239.820            3.800
# 2075258               0.934                 0.000  239.700            3.800
# 2075259               0.932                 0.000  239.550            3.800
#
# ...

# %%
Household_data.set_index( 'DateTime' , inplace= True )
Household_data.index = pd.to_datetime(Household_data.index)

# %%
Household_data
# Out:
#                     Global_active_power Global_reactive_power  Voltage  \
# DateTime
# 2006-12-16 17:24:00               4.216                 0.418  234.840
# 2006-12-16 17:25:00               5.360                 0.436  233.630
# 2006-12-16 17:26:00               5.374                 0.498  233.290
# 2006-12-16 17:27:00               5.388                 0.502  233.740
# 2006-12-16 17:28:00               3.666                 0.528  235.680
# ...                                 ...                   ...      ...
# 2010-11-26 20:58:00               0.946                 0.000  240.430
# 2010-11-26 20:59:00               0.944                 0.000  240.000
# 2010-11-26 21:00:00               0.938                 0.000  239.820
# 2010-11-26 21:01:00               0.934                 0.000  239.700
# 2010-11-26 21:02:00               0.932                 0.000  239.550
#
#                     Global_intensity Sub_metering_1 Sub_metering_2  \
# DateTime
# ...

# %%
Household_data
# Out:
#                     Global_active_power Global_reactive_power  Voltage  \
# DateTime
# 2006-12-16 17:24:00               4.216                 0.418  234.840
# 2006-12-16 17:25:00               5.360                 0.436  233.630
# 2006-12-16 17:26:00               5.374                 0.498  233.290
# 2006-12-16 17:27:00               5.388                 0.502  233.740
# 2006-12-16 17:28:00               3.666                 0.528  235.680
# ...                                 ...                   ...      ...
# 2010-11-26 20:58:00               0.946                 0.000  240.430
# 2010-11-26 20:59:00               0.944                 0.000  240.000
# 2010-11-26 21:00:00               0.938                 0.000  239.820
# 2010-11-26 21:01:00               0.934                 0.000  239.700
# 2010-11-26 21:02:00               0.932                 0.000  239.550
#
#                     Global_intensity Sub_metering_1 Sub_metering_2  \
# DateTime
# ...

# %%
Household_data.isna().sum()
# Out:
# Global_active_power          0
# Global_reactive_power        0
# Voltage                      0
# Global_intensity             0
# Sub_metering_1               0
# Sub_metering_2               0
# Sub_metering_3           25979
# dtype: int64

# %%
Household_data = Household_data.fillna(method='ffill')
Household_data.isna().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %%
Household_data.dtypes
# Out:
# Global_active_power      object
# Global_reactive_power    object
# Voltage                  object
# Global_intensity         object
# Sub_metering_1           object
# Sub_metering_2           object
# Sub_metering_3           object
# dtype: object

# %%
#Household_data['Global_active_power'] = Household_data['Global_active_power'].astype(float)
Household_data['Global_active_power'] = pd.to_numeric(Household_data['Global_active_power'], errors='coerce')
Household_data['Global_reactive_power'] = pd.to_numeric(Household_data['Global_reactive_power'], errors='coerce')
Household_data['Voltage'] = pd.to_numeric(Household_data['Voltage'], errors='coerce')
Household_data['Global_intensity'] = pd.to_numeric(Household_data['Global_intensity'], errors='coerce')
Household_data['Sub_metering_1'] = pd.to_numeric(Household_data['Sub_metering_1'], errors='coerce')
Household_data['Sub_metering_2'] = pd.to_numeric(Household_data['Sub_metering_2'], errors='coerce')
Household_data['Sub_metering_3'] = pd.to_numeric(Household_data['Sub_metering_3'], errors='coerce')
Household_data.dtypes
# Out:
# Global_active_power      float64
# Global_reactive_power    float64
# Voltage                  float64
# Global_intensity         float64
# Sub_metering_1           float64
# Sub_metering_2           float64
# Sub_metering_3           float64
# dtype: object

# %%
Household_data = Household_data.resample('D').mean()
#print(pd.DataFrame(Household_data.resample('W',kind='period').sum()))

# %%
Household_data=Household_data.fillna(method ='ffill')

# %%
#Household_data.dropna()
Household_data.isna().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %%
import statsmodels.api as sm
from pylab import rcParams
import matplotlib.pyplot as plt
rcParams[ 'figure.figsize' ] = 15 , 8
decompose_series = sm.tsa.seasonal_decompose(Household_data[ 'Voltage' ], model= 'additive' )
decompose_series.plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
adf_result = adfuller(Household_data['Global_active_power'])
print( adf_result[0])
print(adf_result[1])
#print( f )
#print( f )
print(adf_result[ 2 ])
adf_result[ 3 ]
adf_result[ 4 ]
#for k, v in adf_result[ 4 ].items():
#    print( f' {k} : {v} ' )
# Out:
# -9.484168153742212
# 3.8020170353759993e-16
# 7
# {'1%': -3.4348709954268384,
#  '5%': -2.863536715724964,
#  '10%': -2.567833035595811}
